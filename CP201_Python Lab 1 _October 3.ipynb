# %% [markdown]
# ## Session 1: Introduction to Jupyter Notebooks and Python
#
# ### 1. An Introduction to the Environment
#
# This first session will cover the basics of Python, and introduce elements that will help you get familiar with Python as an interactive computational environment for exploring data. The material is presented in an interactive environment that runs within your web browser, called a Jupyter Notebook. It allows presentation of text and graphics to be combined with Python code that can be run interactively, with the results appearing inline. We are looking at a Jupyter notebook now. Note that Jupyter is a relatively recent name for this so sometimes you may still see it referred to as an IPython noteboook. Jupyter is just the new version of IPython notebooks, but now also supports a variety of other languages and tools.
#
# Let's start by getting familiar with the Jupyter Notebook and how it works.
#
# ### 1.1 Launching a Jupyter Notebook on DataHub
#
# In this course we will be using hosted computing facilities to make it easy to start learning to code in Python and to leverage university computing infrastructure. In class we will use datahub, and you can use a Calnet login to connect it at http://datahub.berkeley.edu.

# %% [markdown]
# ### 1.2 Using Jupyter Notebooks
#
# Once you launch the Jupyter Notebook, and the Notebook opens up in your browser, you will be looking at a directory of the folder you were in when you launched the notebook. you can either load an existing notebook if you see one in the directory, or create a new one.
#
# The Jupyter Notebook is made up of cells.  Some cells are known as ***markdown cells***, which contain html text. (Like this cell!)
#
# You can edit the contents of a cell by double-clicking on it. Try it on this cell. When you are ready to save a markdown cell, just use Shift-Enter.
#
# You can use Markdown syntax to format your text. Documentation on the markdown syntax is available here: https://www.markdownguide.org/basic-syntax/

# %% [markdown]
# ### 1.3 Code Cells
#
# In addition to markdown cells, Jupyter has ***code cells***, which contain programming code.  It's in these cells that the magic happens!  Try it - put your curser in the cell below, and hit "Ctrl-Enter" to run the code cell.

# %%
import math
math.sqrt(52)
# Out:
# 7.211102550927978

# %% [markdown]
# That was cool!!!  Try changing the 144 to a different number, and run the cell again.

# %% [markdown]
# ### 1.4 Learning the Python Language
#
# Python is a language, and like natural human languages, it takes time to learn.  There is vocabulary, or "syntax," as well as rules for how that syntax is presented.  Both of these just take practice, practice, practice.  We will teach you the rules, but you need to practice on your own.
#
# However, programming languages differ from natural language in one important way:
#
# > The rules are rigid. If you're proficient in a natural language, you can understand a non-proficient speaker, glossing over small mistakes. A computer running Python code is not smart enough to do that.
#
# Whenever you write code, you'll make mistakes. Errors are okay; even experienced programmers make many errors. When you make an error, you just have to find the source of the problem, fix it, and move on. Fixing it can take a long time.  A long long time.

# %% [markdown]
# ### 2. Moving from Excel to Python
#
# We're going to jump right into the Python language by replicating what we did with our ACS data in a programming language, rather than in Excel.  We're starting with a very simple datasheet that includes data on census tracts in Oakland for housing units, including the number of housing units that are rented, and the number that are owned.

# %% [markdown]
# #### 2.1 Introduction to Tables
#
# A table is a fundamental object type for representing data sets. Each column of a table data structure must contain values of the same kind. For example, a table can have a column of integers or a column of strings. We can create a table from scratch or from a CSV file. Let's try reading our ACS .csv file into a table.

# %% [markdown]
# One of the challenging things about using open source software is that it is rarely presented as a "complete" software package.  If you're working in Excel, you don't need to go outside of the program to insert a "square root of the sum of squares" equation, for example.  It's a function in Excel. With open source software, different functions were created by different programmers, and we often have to "call" in that external program to do what we want. These are often called libraries.
#
# Two important libraries in Python are:
#
# >**numpy**: a general-purpose array-processing package. What does this mean?  A package that let's us work with tables (also known as arrays).
#
# >**pandas**: a software library for data manipulation and analysis.
#
# We install these two libraries with the following commands. The abbreviation will be what we use to "call" functions that belong to that library.

# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('Lab5_Tenure_Alameda.csv', delimiter = ',')
# Out:
#                                           Census Tract         County  \
# 0        Census Tract 9900, Alameda County, California        Alameda
# 1        Census Tract 4432, Alameda County, California        Alameda
# 2     Census Tract 4511.02, Alameda County, California        Alameda
# 3        Census Tract 4420, Alameda County, California        Alameda
# 4        Census Tract 4261, Alameda County, California        Alameda
# 5     Census Tract 4351.03, Alameda County, California        Alameda
# 6     Census Tract 4403.32, Alameda County, California        Alameda
# 7        Census Tract 4304, Alameda County, California        Alameda
# 8        Census Tract 4046, Alameda County, California        Alameda
# 9     Census Tract 4431.03, Alameda County, California        Alameda
# 10    Census Tract 4364.02, Alameda County, California        Alameda
# 11       Census Tract 4211, Alameda County, California        Alameda
# 12    Census Tract 4505.02, Alameda County, California        Alameda
# 13    Census Tract 4515.05, Alameda County, California        Alameda
# 14       Census Tract 4051, Alameda County, California        Alameda
# 15    Census Tract 4507.51, Alameda County, California        Alameda
# 16       Census Tract 4212, Alameda County, California        Alameda
# 17    Census Tract 4431.02, Alameda County, California        Alameda
# 18       Census Tract 4302, Alameda County, California        Alameda
# 19    Census Tract 4431.05, Alameda County, California        Alameda
# 20    Census Tract 4045.01, Alameda County, California        Alameda
# 21    Census Tract 4301.01, Alameda County, California        Alameda
# 22    Census Tract 4301.02, Alameda County, California        Alameda
# 23    Census Tract 4507.01, Alameda County, California        Alameda
# 24       Census Tract 4303, Alameda County, California        Alameda
# 25       Census Tract 4047, Alameda County, California        Alameda
# 26    Census Tract 4433.01, Alameda County, California        Alameda
# 27    Census Tract 4507.44, Alameda County, California        Alameda
# 28       Census Tract 4100, Alameda County, California        Alameda
# 29    Census Tract 4283.02, Alameda County, California        Alameda
# ..                                                 ...            ...
# 736  Census Tract 209, San Francisco County, Califo...  San Francisco
# 737  Census Tract 155, San Francisco County, Califo...  San Francisco
# 738  Census Tract 113, San Francisco County, Califo...  San Francisco
# 739  Census Tract 231.03, San Francisco County, Cal...  San Francisco
# 740  Census Tract 162, San Francisco County, Califo...  San Francisco
# 741  Census Tract 176.01, San Francisco County, Cal...  San Francisco
# 742  Census Tract 106, San Francisco County, Califo...  San Francisco
# 743  Census Tract 117, San Francisco County, Califo...  San Francisco
# 744  Census Tract 111, San Francisco County, Califo...  San Francisco
# 745  Census Tract 161, San Francisco County, Califo...  San Francisco
# 746  Census Tract 122.01, San Francisco County, Cal...  San Francisco
# 747  Census Tract 107, San Francisco County, Califo...  San Francisco
# 748  Census Tract 121, San Francisco County, Califo...  San Francisco
# 749  Census Tract 119.02, San Francisco County, Cal...  San Francisco
# 750  Census Tract 124.02, San Francisco County, Cal...  San Francisco
# 751  Census Tract 611, San Francisco County, Califo...  San Francisco
# 752  Census Tract 122.02, San Francisco County, Cal...  San Francisco
# 753  Census Tract 125.01, San Francisco County, Cal...  San Francisco
# 754  Census Tract 118, San Francisco County, Califo...  San Francisco
# 755  Census Tract 601, San Francisco County, Califo...  San Francisco
# 756  Census Tract 120, San Francisco County, Califo...  San Francisco
# 757  Census Tract 332.01, San Francisco County, Cal...  San Francisco
# 758  Census Tract 123.01, San Francisco County, Cal...  San Francisco
# 759  Census Tract 124.01, San Francisco County, Cal...  San Francisco
# 760  Census Tract 125.02, San Francisco County, Cal...  San Francisco
# 761  Census Tract 123.02, San Francisco County, Cal...  San Francisco
# 762  Census Tract 332.03, San Francisco County, Cal...  San Francisco
# 763  Census Tract 179.02, San Francisco County, Cal...  San Francisco
# 764  Census Tract 332.04, San Francisco County, Cal...  San Francisco
# 765  Census Tract 9803, San Francisco County, Calif...  San Francisco
#
#      Total Population  Occupied housing units  \
# 0                   0                       0
# 1                3704                    1171
# 2                4011                    1322
# 3                3212                     997
# 4                5922                    2116
# 5                6403                    2045
# 6                3310                     866
# 7                2046                     747
# 8                4353                    1800
# 9                4029                    1166
# 10               2618                     994
# 11               1992                     842
# 12               4185                    1495
# 13               3337                    1137
# 14               4197                    1579
# 15               2115                     656
# 16               3563                    1464
# 17               4611                    1410
# 18               6916                    2444
# 19               4456                    1374
# 20               1677                     688
# 21               6523                    2202
# 22               2285                     894
# 23               8075                    2605
# 24               3670                    1320
# 25               1954                     810
# 26               4074                    1207
# 27               4831                    1553
# 28               2805                    1137
# 29               7074                    2661
# ..                ...                     ...
# 736              4372                    1742
# 737              3622                    2176
# 738              3143                    1527
# 739              3725                    1202
# 740              2541                    1594
# 741              7630                    4321
# 742              3894                    2015
# 743              1783                    1012
# 744              5164                    3073
# 745              5366                    2756
# 746              4567                    2667
# 747              5592                    2778
# 748              3833                    2194
# 749              2598                    1700
# 750              3974                    2254
# 751              4307                    2135
# 752              2986                    1514
# 753              5335                    2205
# 754              1500                     695
# 755              3235                    1110
# 756              3833                    2546
# 757              3683                     647
# 758              2734                    1559
# 759              5075                    2698
# 760              3821                    2034
# 761              3073                    2098
# 762              3472                    1478
# 763              2880                     656
# 764              3821                    1598
# 765               171                      34
#
#      Occupied housing units: Owner Occupied  \
# 0                                         0
# 1                                      1131
# 2                                      1268
# 3                                       926
# 4                                      1958
# 5                                      1885
# 6                                       792
# 7                                       682
# 8                                      1642
# 9                                      1062
# 10                                      904
# 11                                      765
# 12                                     1357
# 13                                     1031
# 14                                     1426
# 15                                      592
# 16                                     1320
# 17                                     1271
# 18                                     2196
# 19                                     1230
# 20                                      612
# 21                                     1957
# 22                                      794
# 23                                     2302
# 24                                     1163
# 25                                      713
# 26                                     1062
# 27                                     1366
# 28                                      991
# 29                                     2315
# ..                                      ...
# 736                                     226
# 737                                     264
# 738                                     158
# 739                                     120
# 740                                     155
# 741                                     407
# 742                                     182
# 743                                      87
# 744                                     236
# 745                                     196
# 746                                     152
# 747                                     154
# 748                                      99
# 749                                      73
# 750                                      94
# 751                                      78
# 752                                      39
# 753                                      55
# 754                                      13
# 755                                      17
# 756                                      33
# 757                                       4
# 758                                       8
# 759                                      13
# 760                                       4
# 761                                       4
# 762                                       1
# 763                                       0
# 764                                       0
# 765                                       0
#
#      Occupied housing units: Renter occupied
# 0                                          0
# 1                                         40
# 2                                         54
# 3                                         71
# 4                                        158
# 5                                        160
# 6                                         74
# 7                                         65
# 8                                        158
# 9                                        104
# 10                                        90
# 11                                        77
# 12                                       138
# 13                                       106
# 14                                       153
# 15                                        64
# 16                                       144
# 17                                       139
# 18                                       248
# 19                                       144
# 20                                        76
# 21                                       245
# 22                                       100
# 23                                       303
# 24                                       157
# 25                                        97
# 26                                       145
# 27                                       187
# 28                                       146
# 29                                       346
# ..                                       ...
# 736                                     1516
# 737                                     1912
# 738                                     1369
# 739                                     1082
# 740                                     1439
# 741                                     3914
# 742                                     1833
# 743                                      925
# 744                                     2837
# 745                                     2560
# 746                                     2515
# 747                                     2624
# 748                                     2095
# 749                                     1627
# 750                                     2160
# 751                                     2057
# 752                                     1475
# 753                                     2150
# 754                                      682
# 755                                     1093
# 756                                     2513
# 757                                      643
# 758                                     1551
# 759                                     2685
# 760                                     2030
# 761                                     2094
# 762                                     1477
# 763                                      656
# 764                                     1598
# 765                                       34
#
# [766 rows x 6 columns]

# %% [markdown]
# So cool!!!!  But, it might be helpful to give the dataset a name, and then just look at the first few lines, rather than seeing the full dataset.

# %%
tenure_2017 = pd.read_csv('Lab5_Tenure_Alameda.csv', delimiter = ',')

# %%
tenure_2017.head(5)
# Out:
#                                        Census Tract   County  \
# 0     Census Tract 9900, Alameda County, California  Alameda
# 1     Census Tract 4432, Alameda County, California  Alameda
# 2  Census Tract 4511.02, Alameda County, California  Alameda
# 3     Census Tract 4420, Alameda County, California  Alameda
# 4     Census Tract 4261, Alameda County, California  Alameda
#
#    Total Population  Occupied housing units  \
# 0                 0                       0
# 1              3704                    1171
# 2              4011                    1322
# 3              3212                     997
# 4              5922                    2116
#
#    Occupied housing units: Owner Occupied  \
# 0                                       0
# 1                                    1131
# 2                                    1268
# 3                                     926
# 4                                    1958
#
#    Occupied housing units: Renter occupied
# 0                                        0
# 1                                       40
# 2                                       54
# 3                                       71
# 4                                      158

# %% [markdown]
# What if I just want to look at a couple of columns?

# %%
tenure_2017[['Occupied housing units', 'Occupied housing units: Renter occupied']].head(5)
# Out:
#    Occupied housing units  Occupied housing units: Renter occupied
# 0                       0                                        0
# 1                    1171                                       40
# 2                    1322                                       54
# 3                     997                                       71
# 4                    2116                                      158

# %% [markdown]
# Long column names are a pain, because we have to type a lot and it's easy to make a typo. One approach is to clean up your datasheet in Excel before reading it into Python.  But let's practice renaming columns.

# %%
tenure_2017.rename(columns={'Total Population': 'Total_Pop', 'Occupied housing units':'HU', 'Occupied housing units: Owner Occupied': 'Owner_HU', "Occupied housing units:Renter occupied": "Renter_HU"}, inplace=True)

# %%
tenure_2017.head(5)
# Out:
#                                        Census Tract   County  Total_Pop    HU  \
# 0     Census Tract 9900, Alameda County, California  Alameda          0     0
# 1     Census Tract 4432, Alameda County, California  Alameda       3704  1171
# 2  Census Tract 4511.02, Alameda County, California  Alameda       4011  1322
# 3     Census Tract 4420, Alameda County, California  Alameda       3212   997
# 4     Census Tract 4261, Alameda County, California  Alameda       5922  2116
#
#    Owner_HU  Occupied housing units: Renter occupied
# 0         0                                        0
# 1      1131                                       40
# 2      1268                                       54
# 3       926                                       71
# 4      1958                                      158
